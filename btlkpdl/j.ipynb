# %%
import os

if os.path.exists("label_encoder.pkl"):
    print("✅ File label_encoder.pkl đã tồn tại.")
else:
    print("❌ File label_encoder.pkl không tồn tại. Hãy kiểm tra lại.")
# Out:
# ❌ File label_encoder.pkl không tồn tại. Hãy kiểm tra lại.

# %%
import os

def print_directory_structure(root_dir, indent=""):
    try:
        items = os.listdir(root_dir)
        for item in items:
            item_path = os.path.join(root_dir, item)
            if os.path.isdir(item_path):
                print(f"{indent}📂 {item}")
                print_directory_structure(item_path, indent + "  ")
            else:
                print(f"{indent}📄 {item}")
    except Exception as e:
        print(f"Lỗi khi đọc thư mục {root_dir}: {e}")

# Thay đổi đường dẫn này nếu cần
project_path = "E:/btlxla"

print(f"📌 Cấu trúc thư mục trong {project_path}:")
print_directory_structure(project_path)
# Out:
# 📌 Cấu trúc thư mục trong E:/btlxla:
# 📄 app.py
# 📂 btlkpdl
#   📄 label_encoder.pkl
#   📂 New folder
#   📄 nhandienkhuonmat.ipynb
# 📂 cmake-4.0.0-rc3-windows-x86_64
#   📂 bin
#     📄 cmake-gui.exe
#     📄 cmake.exe
#     📄 cmcldeps.exe
#     📄 cpack.exe
#     📄 ctest.exe
#   📂 doc
#     📂 cmake
#       📄 cmake.org.html
#       📄 CMake.qch
#       📂 cmcppdap
#         📄 NOTICE
#       📂 cmcurl
#         📄 COPYING
#       📂 cmlibarchive
#         📄 COPYING
#       📂 cmliblzma
#         📄 COPYING
#       📂 cmlibrhash
#         📄 COPYING
#       📂 cmlibuv
#         📄 LICENSE
#       📂 cmnghttp2
#         📄 COPYING
#       📂 cmsys
#         📄 Copyright.txt
#       📂 cmzlib
#         📄 Copyright.txt
#       📂 cmzstd
#         📄 LICENSE
#       📄 CONTRIBUTORS.rst
#       📂 html
#         📂 command
#           📄 add_compile_definitions.html
#           📄 add_compile_options.html
#           📄 add_custom_command.html
#           📄 add_custom_target.html
#           📄 add_definitions.html
# ...
